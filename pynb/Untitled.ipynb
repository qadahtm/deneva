# %%
wh_cnt = 10
d_cnt = 10
max_size = 10000
t_cnt = 10
p_size = int(max_size / t_cnt)
for wh in range(wh_cnt):
    for d in range(d_cnt):
        w_rid = wh*p_size
        d_rid = w_rid + d
        wt_id = 
        print("w_id={}, d_id={}, w_rid={},d_rid={}".format(wh,d, w_rid, d_rid))
# Out:
# w_id=0, d_id=0, w_rid=0,d_rid=0
# w_id=0, d_id=1, w_rid=0,d_rid=1
# w_id=0, d_id=2, w_rid=0,d_rid=2
# w_id=0, d_id=3, w_rid=0,d_rid=3
# w_id=0, d_id=4, w_rid=0,d_rid=4
# w_id=0, d_id=5, w_rid=0,d_rid=5
# w_id=0, d_id=6, w_rid=0,d_rid=6
# w_id=0, d_id=7, w_rid=0,d_rid=7
# w_id=0, d_id=8, w_rid=0,d_rid=8
# w_id=0, d_id=9, w_rid=0,d_rid=9
# w_id=1, d_id=0, w_rid=1000,d_rid=1000
# w_id=1, d_id=1, w_rid=1000,d_rid=1001
# w_id=1, d_id=2, w_rid=1000,d_rid=1002
# w_id=1, d_id=3, w_rid=1000,d_rid=1003
# w_id=1, d_id=4, w_rid=1000,d_rid=1004
# w_id=1, d_id=5, w_rid=1000,d_rid=1005
# w_id=1, d_id=6, w_rid=1000,d_rid=1006
# w_id=1, d_id=7, w_rid=1000,d_rid=1007
# w_id=1, d_id=8, w_rid=1000,d_rid=1008
# w_id=1, d_id=9, w_rid=1000,d_rid=1009
# w_id=2, d_id=0, w_rid=2000,d_rid=2000
# w_id=2, d_id=1, w_rid=2000,d_rid=2001
# w_id=2, d_id=2, w_rid=2000,d_rid=2002
# w_id=2, d_id=3, w_rid=2000,d_rid=2003
# w_id=2, d_id=4, w_rid=2000,d_rid=2004
# w_id=2, d_id=5, w_rid=2000,d_rid=2005
# ...
